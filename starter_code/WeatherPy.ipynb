# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    city = city.replace(" ", "%20")
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(len(cities))
# Out:
# 633

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = (f"http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID={api_key}&q=")

city_name = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lon = []
max_temp = []
wind_speed = []

count = 1
print("Data aquisition...")
print("=======================")
for city in cities:
        try:
            response = requests.get(url + city).json()
            
            city_name.append(response["name"])
            cloudiness.append(response["clouds"]["all"])
            country.append(response["sys"]["country"])
            date.append(response["dt"])
            humidity.append(response["main"]["humidity"])
            max_temp.append(response["main"]["temp_max"])
            lat.append(response["coord"]["lat"])
            lon.append(response["coord"]["lon"])
            wind_speed.append(response["wind"]["speed"])
            city_count = response["name"]
          
            print(f"Processing city {count} || {city_count}")
            print(url + city)
            count = count + 1
            time.sleep(1.05)
            
        except:
            print(f"Processing city {count} || ... City not found... Skipping...")
            count = count + 1
        continue
print("=======================")
print("Complete")
# Out:
# Data aquisition...
# =======================
# Processing city 1 || Mataura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=mataura
# Processing city 2 || Wagar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=wagar
# Processing city 3 || Albany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=albany
# Processing city 4 || Port Alfred
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=port%20alfred
# Processing city 5 || Tautira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=tautira
# Processing city 6 || Hasaki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=hasaki
# Processing city 7 || Bluff
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=bluff
# Processing city 8 || Provideniya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=provideniya
# Processing city 9 || ... City not found... Skipping...
# Processing city 10 || Fukue
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=fukue
# Processing city 11 || Dunedin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=dunedin
# Processing city 12 || Ahipara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=ahipara
# Processing city 13 || Rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=rikitea
# Processing city 14 || Chuy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=chuy
# Processing city 15 || Alberton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=alberton
# Processing city 16 || Guerrero Negro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=guerrero%20negro
# Processing city 17 || Ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=ushuaia
# Processing city 18 || ... City not found... Skipping...
# Processing city 19 || Umm Lajj
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=umm%20lajj
# Processing city 20 || Hobart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=hobart
# Processing city 21 || Puerto Ayora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=puerto%20ayora
# Processing city 22 || Khatanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=khatanga
# Processing city 23 || Rawson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=rawson
# Processing city 24 || Kapaa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=kapaa
# Processing city 25 || ... City not found... Skipping...
# Processing city 26 || Bredasdorp
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=bredasdorp
# Processing city 27 || Jamestown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=jamestown
# Processing city 28 || Maragogi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=maragogi
# Processing city 29 || Punta Arenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=punta%20arenas
# Processing city 30 || ... City not found... Skipping...
# Processing city 31 || Vardo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=vardo
# Processing city 32 || Ancud
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=ancud
# Processing city 33 || Youkounkoun
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=youkounkoun
# Processing city 34 || Avarua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=avarua
# Processing city 35 || Port Elizabeth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=port%20elizabeth
# Processing city 36 || Ilulissat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=ilulissat
# Processing city 37 || Joniskis
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=joniskis
# Processing city 38 || Kodiak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=kodiak
# Processing city 39 || Atar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=atar
# Processing city 40 || Thompson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=thompson
# Processing city 41 || Mar del Plata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=mar%20del%20plata
# Processing city 42 || ... City not found... Skipping...
# Processing city 43 || Kortkeros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=kortkeros
# Processing city 44 || Eyrarbakki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=eyrarbakki
# Processing city 45 || Klamath Falls
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=klamath%20falls
# Processing city 46 || Castro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=castro
# Processing city 47 || ... City not found... Skipping...
# Processing city 48 || Wanning
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=wanning
# Processing city 49 || Chimore
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=chimore
# Processing city 50 || ... City not found... Skipping...
# Processing city 51 || Sorata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=sorata
# Processing city 52 || Pevek
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=pevek
# Processing city 53 || Kavaratti
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=kavaratti
# Processing city 54 || Tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=tuktoyaktuk
# Processing city 55 || Nicoya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=nicoya
# Processing city 56 || ... City not found... Skipping...
# Processing city 57 || Clarence Town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=clarence%20town
# Processing city 58 || ... City not found... Skipping...
# Processing city 59 || ... City not found... Skipping...
# Processing city 60 || Ponta do Sol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=ponta%20do%20sol
# Processing city 61 || Pouembout
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=pouembout
# Processing city 62 || Busselton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=busselton
# Processing city 63 || Ribas do Rio Pardo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=ribas%20do%20rio%20pardo
# Processing city 64 || Meulaboh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=meulaboh
# Processing city 65 || Saint-Philippe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=saint-philippe
# Processing city 66 || Dikson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=dikson
# Processing city 67 || Sao Filipe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=sao%20filipe
# Processing city 68 || Mahebourg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=mahebourg
# Processing city 69 || Cidreira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=cidreira
# Processing city 70 || Rio Grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=rio%20grande
# Processing city 71 || Kruisfontein
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=kruisfontein
# Processing city 72 || Usinsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=usinsk
# Processing city 73 || Requena
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=requena
# Processing city 74 || Hermanus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=hermanus
# Processing city 75 || Komsomolskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=komsomolskiy
# Processing city 76 || Itoman
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=itoman
# Processing city 77 || Cape Town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=cape%20town
# Processing city 78 || Torbay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=torbay
# Processing city 79 || Lindas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=lindas
# Processing city 80 || ... City not found... Skipping...
# Processing city 81 || Vestmannaeyjar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=vestmannaeyjar
# Processing city 82 || Grand Gaube
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=grand%20gaube
# Processing city 83 || Longyearbyen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=longyearbyen
# Processing city 84 || Ulaangom
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=ulaangom
# Processing city 85 || Teya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=teya
# Processing city 86 || ... City not found... Skipping...
# Processing city 87 || Tiksi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=tiksi
# Processing city 88 || Biltine
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=biltine
# Processing city 89 || Eenhana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=eenhana
# Processing city 90 || Kloulklubed
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=kloulklubed
# Processing city 91 || Jackville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=jacqueville
# Processing city 92 || Nabire
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=nabire
# Processing city 93 || Clyde River
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=clyde%20river
# Processing city 94 || Atuona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=atuona
# Processing city 95 || Alofi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=alofi
# Processing city 96 || Pangai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=pangai
# Processing city 97 || ... City not found... Skipping...
# Processing city 98 || Naica
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=naica
# Processing city 99 || Vila Franca do Campo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=vila%20franca%20do%20campo
# Processing city 100 || ... City not found... Skipping...
# Processing city 101 || Eyl
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=eyl
# Processing city 102 || Pocosol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=pocosol
# Processing city 103 || Severo-Kurilsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=severo-kurilsk
# Processing city 104 || Vaini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=vaini
# Processing city 105 || ... City not found... Skipping...
# Processing city 106 || Nago
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=nago
# Processing city 107 || Krasnyy Luch
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=krasnyy%20luch
# Processing city 108 || New Norfolk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=new%20norfolk
# Processing city 109 || ... City not found... Skipping...
# Processing city 110 || Te Anau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=te%20anau
# Processing city 111 || Flinders
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=flinders
# Processing city 112 || Borazjan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=borazjan
# Processing city 113 || Chokurdakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=chokurdakh
# Processing city 114 || ... City not found... Skipping...
# Processing city 115 || ... City not found... Skipping...
# Processing city 116 || ... City not found... Skipping...
# Processing city 117 || Kaka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=kaka
# Processing city 118 || ... City not found... Skipping...
# Processing city 119 || Victoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=labuan
# Processing city 120 || Homer
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=homer
# Processing city 121 || Butaritari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=butaritari
# Processing city 122 || Dingle
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=dingle
# Processing city 123 || Kaitangata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=kaitangata
# Processing city 124 || Canutama
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=canutama
# Processing city 125 || Mumford
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=mumford
# Processing city 126 || Doha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=doha
# Processing city 127 || Wahpeton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=wahpeton
# Processing city 128 || Sao Carlos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=sao%20carlos
# Processing city 129 || Kokopo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=kokopo
# Processing city 130 || Zhezkazgan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=zhezkazgan
# Processing city 131 || Upernavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=upernavik
# Processing city 132 || Bijie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=bijie
# Processing city 133 || Owando
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=owando
# Processing city 134 || ... City not found... Skipping...
# Processing city 135 || Zhigansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=zhigansk
# Processing city 136 || ... City not found... Skipping...
# Processing city 137 || Gajendragarh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=gajendragarh
# Processing city 138 || Burbank
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=burbank
# Processing city 139 || Santa Cruz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=santa%20cruz
# Processing city 140 || Sioux Lookout
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=sioux%20lookout
# Processing city 141 || Tasiilaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=tasiilaq
# Processing city 142 || ... City not found... Skipping...
# Processing city 143 || Ostrovnoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=ostrovnoy
# Processing city 144 || Marawi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=marawi
# Processing city 145 || Porto Walter
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=porto%20walter
# Processing city 146 || Hilo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=hilo
# Processing city 147 || Nalut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=nalut
# Processing city 148 || Airai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=airai
# Processing city 149 || East London
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=east%20london
# Processing city 150 || Bambous Virieux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=bambous%20virieux
# Processing city 151 || Barrow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=barrow
# Processing city 152 || San Carlos de Bariloche
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=san%20carlos%20de%20bariloche
# Processing city 153 || Srednekolymsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=srednekolymsk
# Processing city 154 || Pemba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=pemba
# Processing city 155 || Port Augusta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=port%20augusta
# Processing city 156 || Alice Springs
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=alice%20springs
# Processing city 157 || Puerto Escondido
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=puerto%20escondido
# Processing city 158 || Tamandare
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=tamandare
# Processing city 159 || Kaeo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=kaeo
# Processing city 160 || Gat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=gat
# Processing city 161 || Almeria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=almeria
# Processing city 162 || Shingu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=shingu
# Processing city 163 || Mayenne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=mayenne
# Processing city 164 || Simpsonville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=simpsonville
# Processing city 165 || Hithadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=hithadhoo
# Processing city 166 || ... City not found... Skipping...
# Processing city 167 || Dwarka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=dwarka
# Processing city 168 || Phayao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=phayao
# Processing city 169 || ... City not found... Skipping...
# Processing city 170 || Koungheul
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=koungheul
# Processing city 171 || Buta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=buta
# Processing city 172 || Naze
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=naze
# Processing city 173 || Talnakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=talnakh
# Processing city 174 || Goundam
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=goundam
# Processing city 175 || Cabo San Lucas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=cabo%20san%20lucas
# Processing city 176 || Gornozavodsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=gornozavodsk
# Processing city 177 || ... City not found... Skipping...
# Processing city 178 || ... City not found... Skipping...
# Processing city 179 || Birin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=birin
# Processing city 180 || Valparaiso
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=valparaiso
# Processing city 181 || Amantea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=amantea
# Processing city 182 || ... City not found... Skipping...
# Processing city 183 || ... City not found... Skipping...
# Processing city 184 || Constitucion
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=constitucion
# Processing city 185 || Deder
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=deder
# Processing city 186 || Smoky Lake
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=smoky%20lake
# Processing city 187 || Lebu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=lebu
# Processing city 188 || Cayenne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=cayenne
# Processing city 189 || Esfarayen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=esfarayen
# Processing city 190 || Kalmunai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=kalmunai
# Processing city 191 || Consett
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=consett
# Processing city 192 || Mayor Pablo Lagerenza
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=mayor%20pablo%20lagerenza
# Processing city 193 || Lorengau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=lorengau
# Processing city 194 || Carutapera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=carutapera
# Processing city 195 || Leshukonskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=leshukonskoye
# Processing city 196 || Saskylakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=saskylakh
# Processing city 197 || Ambilobe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=ambilobe
# Processing city 198 || Faya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=faya
# Processing city 199 || Cherskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=cherskiy
# Processing city 200 || Morrope
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=morrope
# Processing city 201 || Sorong
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=sorong
# Processing city 202 || Mineiros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=mineiros
# Processing city 203 || Krasnogorskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=krasnogorskoye
# Processing city 204 || Havelock
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=havelock
# Processing city 205 || Ikongo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=ikongo
# Processing city 206 || Elat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=elat
# Processing city 207 || Port Hawkesbury
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=port%20hawkesbury
# Processing city 208 || Coquimbo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=coquimbo
# Processing city 209 || Georgetown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=georgetown
# Processing city 210 || Aklavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=aklavik
# Processing city 211 || Bunia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=bunia
# Processing city 212 || Pangody
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=pangody
# Processing city 213 || Outjo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=outjo
# Processing city 214 || Kumluca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=kumluca
# Processing city 215 || Resistencia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=resistencia
# Processing city 216 || Strezhevoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=strezhevoy
# Processing city 217 || Yellowknife
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=yellowknife
# Processing city 218 || ... City not found... Skipping...
# Processing city 219 || Saint-Augustin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=saint-augustin
# Processing city 220 || Sembakung
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=sembakung
# Processing city 221 || Blackfoot
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=blackfoot
# Processing city 222 || Padang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=padang
# Processing city 223 || Evensk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=evensk
# Processing city 224 || Faanui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=faanui
# Processing city 225 || Souillac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=souillac
# Processing city 226 || Kavieng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=kavieng
# Processing city 227 || ... City not found... Skipping...
# Processing city 228 || Alexandria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=alexandria
# Processing city 229 || Luderitz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=luderitz
# Processing city 230 || Turkmenabat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=turkmenabat
# Processing city 231 || Marrakesh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=marrakesh
# Processing city 232 || Kichera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=kichera
# Processing city 233 || ... City not found... Skipping...
# Processing city 234 || Parkes
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=parkes
# Processing city 235 || Skjervoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=skjervoy
# Processing city 236 || Ystad
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=ystad
# Processing city 237 || Lillesand
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=lillesand
# Processing city 238 || La Grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=la%20grande
# Processing city 239 || Tianpeng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=tianpeng
# Processing city 240 || Nelson Bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=nelson%20bay
# Processing city 241 || Viedma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=viedma
# Processing city 242 || ... City not found... Skipping...
# Processing city 243 || Nikolskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=nikolskoye
# Processing city 244 || Yashan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=yashan
# Processing city 245 || Poum
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=poum
# Processing city 246 || ... City not found... Skipping...
# Processing city 247 || Drayton Valley
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=drayton%20valley
# Processing city 248 || Ko Samui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=ko%20samui
# Processing city 249 || ... City not found... Skipping...
# Processing city 250 || Opava
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=opava
# Processing city 251 || Mount Isa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=mount%20isa
# Processing city 252 || Kahului
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=kahului
# Processing city 253 || Apt
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=apt
# Processing city 254 || ... City not found... Skipping...
# Processing city 255 || ... City not found... Skipping...
# Processing city 256 || Sur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=sur
# Processing city 257 || Eskil
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=eskil
# Processing city 258 || Taltal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=taltal
# Processing city 259 || Kambove
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=kambove
# Processing city 260 || Grafton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=grafton
# Processing city 261 || Haines Junction
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=haines%20junction
# Processing city 262 || ... City not found... Skipping...
# Processing city 263 || Aykhal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=aykhal
# Processing city 264 || Beringovskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=beringovskiy
# Processing city 265 || ... City not found... Skipping...
# Processing city 266 || Koutiala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=koutiala
# Processing city 267 || Shunyi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=shunyi
# Processing city 268 || Filingue
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=filingue
# Processing city 269 || Henties Bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=henties%20bay
# Processing city 270 || Broome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=broome
# Processing city 271 || Bathsheba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=bathsheba
# Processing city 272 || ... City not found... Skipping...
# Processing city 273 || Auki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=auki
# Processing city 274 || Okato
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=okato
# Processing city 275 || Huangchuan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=huangchuan
# Processing city 276 || ... City not found... Skipping...
# Processing city 277 || Jilib
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=jilib
# Processing city 278 || Brigantine
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=brigantine
# Processing city 279 || Tarko-Sale
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=tarko-sale
# Processing city 280 || Yerbogachen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=yerbogachen
# Processing city 281 || Los Zacatones
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=los%20zacatones
# Processing city 282 || Findlay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=findlay
# Processing city 283 || Kuytun
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=kuytun
# Processing city 284 || Victoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=victoria
# Processing city 285 || Shimoda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=shimoda
# Processing city 286 || Emporia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=emporia
# Processing city 287 || Daru
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=daru
# Processing city 288 || Geraldton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=geraldton
# Processing city 289 || Massena
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=massena
# Processing city 290 || ... City not found... Skipping...
# Processing city 291 || Marzuq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=marzuq
# Processing city 292 || ... City not found... Skipping...
# Processing city 293 || Nacogdoches
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=nacogdoches
# Processing city 294 || Bafq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=bafq
# Processing city 295 || Corrales
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=corrales
# Processing city 296 || Carnarvon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=carnarvon
# Processing city 297 || San Vicente
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=san%20vicente
# Processing city 298 || Los Llanos de Aridane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=los%20llanos%20de%20aridane
# Processing city 299 || Manokwari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=manokwari
# Processing city 300 || Atherton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=atherton
# Processing city 301 || ... City not found... Skipping...
# Processing city 302 || Yamandu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=yamandu
# Processing city 303 || Puntarenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=puntarenas
# Processing city 304 || Alta Floresta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=alta%20floresta
# Processing city 305 || Christiana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=christiana
# Processing city 306 || Sechura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=sechura
# Processing city 307 || Puerto Carreno
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=puerto%20carreno
# Processing city 308 || Boyabat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=boyabat
# Processing city 309 || Puerto del Rosario
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=puerto%20del%20rosario
# Processing city 310 || Lagoa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=lagoa
# Processing city 311 || ... City not found... Skipping...
# Processing city 312 || Mogadishu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=mogadishu
# Processing city 313 || Helong
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=helong
# Processing city 314 || Port Lincoln
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=port%20lincoln
# Processing city 315 || Kayes
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=kayes
# Processing city 316 || Smithers
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=smithers
# Processing city 317 || ... City not found... Skipping...
# Processing city 318 || Nanchong
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=nanchong
# Processing city 319 || ... City not found... Skipping...
# Processing city 320 || Karratha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=karratha
# Processing city 321 || Jalu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=jalu
# Processing city 322 || Derzhavinsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=derzhavinsk
# Processing city 323 || Garissa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=garissa
# Processing city 324 || Koumac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=koumac
# Processing city 325 || Yertsevo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=yertsevo
# Processing city 326 || Palmer
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=palmer
# Processing city 327 || Mao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=mao
# Processing city 328 || Praia da Vitoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=praia%20da%20vitoria
# Processing city 329 || Antofagasta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=antofagasta
# Processing city 330 || Yulara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=yulara
# Processing city 331 || Tigzirt
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=tigzirt
# Processing city 332 || Biak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=biak
# Processing city 333 || Norman Wells
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=norman%20wells
# Processing city 334 || Tsaratanana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=tsaratanana
# Processing city 335 || Kerns
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=kerns
# Processing city 336 || Yar-Sale
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=yar-sale
# Processing city 337 || Daitari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=daitari
# Processing city 338 || Bara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=bara
# Processing city 339 || Daryapur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=daryapur
# Processing city 340 || Latung
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=latung
# Processing city 341 || Mallaig
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=mallaig
# Processing city 342 || Ust-Barguzin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=ust-barguzin
# Processing city 343 || Kutum
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=kutum
# Processing city 344 || Campina Verde
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=campina%20verde
# Processing city 345 || Marsa Matruh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=marsa%20matruh
# Processing city 346 || Solhan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=solhan
# Processing city 347 || Arraial do Cabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=arraial%20do%20cabo
# Processing city 348 || ... City not found... Skipping...
# Processing city 349 || Alugan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=alugan
# Processing city 350 || ... City not found... Skipping...
# Processing city 351 || San Quintin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=san%20quintin
# Processing city 352 || Qaanaaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=qaanaaq
# Processing city 353 || Ritini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=ritini
# Processing city 354 || ... City not found... Skipping...
# Processing city 355 || Lazaro Cardenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=lazaro%20cardenas
# Processing city 356 || Bambanglipuro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=bambanglipuro
# Processing city 357 || Ixtapa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=ixtapa
# Processing city 358 || Suileng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=suileng
# Processing city 359 || Santa Maria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=santa%20maria
# Processing city 360 || Penzance
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=penzance
# Processing city 361 || Gizo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=gizo
# Processing city 362 || La Asuncion
# ...
# Processing city 518 || Tecoanapa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=tecoanapa
# Processing city 519 || Kazachinskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=kazachinskoye
# Processing city 520 || Hailar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=hailar
# Processing city 521 || Sistranda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=sistranda
# Processing city 522 || Ghorawal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=ghorawal
# Processing city 523 || Codrington
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=codrington
# Processing city 524 || Svetlaya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=svetlaya
# Processing city 525 || Buala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=buala
# Processing city 526 || ... City not found... Skipping...
# Processing city 527 || Adrar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=adrar
# Processing city 528 || Ulladulla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=ulladulla
# Processing city 529 || Araouane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=araouane
# Processing city 530 || Khasan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=khasan
# Processing city 531 || Karangasem
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=karangasem
# Processing city 532 || Lagunas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=lagunas
# Processing city 533 || Mastic
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=mastic
# Processing city 534 || Altamont
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=altamont
# Processing city 535 || Okhotsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=okhotsk
# Processing city 536 || Chumikan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=chumikan
# Processing city 537 || Goya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=goya
# Processing city 538 || Pangnirtung
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=pangnirtung
# Processing city 539 || Nishihara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=nishihara
# Processing city 540 || Synya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=synya
# Processing city 541 || Hayden
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=hayden
# Processing city 542 || San Rafael Abajo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=san%20rafael%20abajo
# Processing city 543 || Tezpur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=tezpur
# Processing city 544 || Valreas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=valreas
# Processing city 545 || Breyten
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=breyten
# Processing city 546 || Lasa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=lasa
# Processing city 547 || Nanganga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=nanganga
# Processing city 548 || Kenai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=kenai
# Processing city 549 || Makat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=makat
# Processing city 550 || Hobyo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=hobyo
# Processing city 551 || Safford
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=safford
# Processing city 552 || Alta Gracia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=alta%20gracia
# Processing city 553 || Namibe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=namibe
# Processing city 554 || Kwinana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=kwinana
# Processing city 555 || Fairbanks
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=fairbanks
# Processing city 556 || Shellbrook
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=shellbrook
# Processing city 557 || Hammond
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=hammond
# Processing city 558 || Kamaishi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=kamaishi
# Processing city 559 || Jieshi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=jieshi
# Processing city 560 || Kontagora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=kontagora
# Processing city 561 || Luanda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=luanda
# Processing city 562 || Richards Bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=richards%20bay
# Processing city 563 || Birao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=birao
# Processing city 564 || Umba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=umba
# Processing city 565 || Keningau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=keningau
# Processing city 566 || Alta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=alta
# Processing city 567 || Mehamn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=mehamn
# Processing city 568 || Jadu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=jadu
# Processing city 569 || Paulo Ramos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=paulo%20ramos
# Processing city 570 || ... City not found... Skipping...
# Processing city 571 || Kamenka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=kamenka
# Processing city 572 || Kalemie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=kalemie
# Processing city 573 || Salalah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=salalah
# Processing city 574 || Kurinjippadi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=kurinjippadi
# Processing city 575 || Hamilton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=hamilton
# Processing city 576 || Balclutha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=balclutha
# Processing city 577 || Hofn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=hofn
# Processing city 578 || Parambu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=parambu
# Processing city 579 || Okakarara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=okakarara
# Processing city 580 || Whitehorse
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=whitehorse
# Processing city 581 || Coihaique
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=coihaique
# Processing city 582 || Urucara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=urucara
# Processing city 583 || Skeldon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=skeldon
# Processing city 584 || Misratah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=misratah
# Processing city 585 || Westport
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=westport
# Processing city 586 || Kendari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=kendari
# Processing city 587 || Satana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=satana
# Processing city 588 || ... City not found... Skipping...
# Processing city 589 || ... City not found... Skipping...
# Processing city 590 || Tuy Hoa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=tuy%20hoa
# Processing city 591 || Santa Cruz de Tenerife
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=santa%20cruz%20de%20tenerife
# Processing city 592 || The Valley
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=the%20valley
# Processing city 593 || Rosarito
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=rosarito
# Processing city 594 || Ihiala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=ihiala
# Processing city 595 || Wonthaggi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=wonthaggi
# Processing city 596 || Kongolo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=kongolo
# Processing city 597 || Eureka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=eureka
# Processing city 598 || Ciudad Bolivar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=ciudad%20bolivar
# Processing city 599 || Boa Esperanca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=boa%20esperanca
# Processing city 600 || Corrientes
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=corrientes
# Processing city 601 || Johi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=johi
# Processing city 602 || Changli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=changli
# Processing city 603 || Bud
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=bud
# Processing city 604 || Nanortalik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=nanortalik
# Processing city 605 || ... City not found... Skipping...
# Processing city 606 || Vigrestad
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=vigrestad
# Processing city 607 || Sungairaya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=sungairaya
# Processing city 608 || Tabou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=tabou
# Processing city 609 || Syracuse
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=syracuse
# Processing city 610 || Porto Novo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=porto%20novo
# Processing city 611 || Omboue
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=omboue
# Processing city 612 || Kerman
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=kerman
# Processing city 613 || Ramon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=ramon
# Processing city 614 || Hambantota
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=hambantota
# Processing city 615 || Thinadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=thinadhoo
# Processing city 616 || Kokoda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=kokoda
# Processing city 617 || Gazanjyk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=gazanjyk
# Processing city 618 || ... City not found... Skipping...
# Processing city 619 || Mandalgovi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=mandalgovi
# Processing city 620 || Berlevag
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=berlevag
# Processing city 621 || ... City not found... Skipping...
# Processing city 622 || Tres Arroyos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=tres%20arroyos
# Processing city 623 || Poddorye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=poddorye
# Processing city 624 || Nantucket
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=nantucket
# Processing city 625 || Lady Frere
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=lady%20frere
# Processing city 626 || Bowen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=bowen
# Processing city 627 || Moroni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=moroni
# Processing city 628 || ... City not found... Skipping...
# Processing city 629 || Huarmey
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=huarmey
# Processing city 630 || Nanga Eboko
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=nanga%20eboko
# Processing city 631 || ... City not found... Skipping...
# Processing city 632 || Fort-Shevchenko
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=fort-shevchenko
# Processing city 633 || Visnes
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=26d156d6f77d74e5b3f1912c1f27555d&q=visnes
# =======================
# Complete

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
WeatherPy_dic = {"Date": date,
                 "City": city_name,
                 "Country": country,
                 "Latitude": lat,
                 "Longitude": lon,
                 "Max Temperature": max_temp,
                 "Winds": wind_speed,
                 "Cloudiness": cloudiness,
                 "Humidity": humidity}

WeatherPy_data = pd.DataFrame(WeatherPy_dic)
WeatherPy_data.to_csv("../Output/WeatherPy_data.csv")
WeatherPy_data.head(10)
# Out:
#          Date         City Country  Latitude  Longitude  Max Temperature  \
# 0  1562632323      Mataura      NZ    -46.19     168.86            51.01
# 1  1562632384        Wagar      US     31.44     -87.99            91.99
# 2  1562632324       Albany      US     42.65     -73.75            77.00
# 3  1562632377  Port Alfred      ZA    -33.59      26.89            64.00
# 4  1562632388      Tautira      PF    -17.73    -149.15            80.60
# 5  1562632237       Hasaki      JP     35.73     140.83            68.00
# 6  1562632357        Bluff      AU    -23.58     149.07            66.62
# 7  1562632338  Provideniya      RU     64.42    -173.23            73.40
# 8  1562632393        Fukue      JP     35.03     136.69            78.01
# 9  1562632193      Dunedin      NZ    -45.87     170.50            52.00
#
#    Winds  Cloudiness  Humidity
# 0  18.99         100        74
# 1   3.27          38        64
# 2   5.82           1        49
# 3   8.01          43        77
# 4   8.05          75        74
# 5  13.87          75        77
# 6   2.80           0        62
# 7  11.18           0        43
# 8  17.22          75        78
# 9   1.99          91        60

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(WeatherPy_data["Latitude"], WeatherPy_data["Max Temperature"], marker="o", s=15)

plt.title("Latitude vs. Max Temperature")
plt.ylabel("Maximum Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

plt.savefig("../Output/temp_vs_latitude.png")

plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(WeatherPy_data["Latitude"], WeatherPy_data["Humidity"], marker="o", s=15)

plt.title("Latitude vs. Humidity")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

plt.savefig("../Output/humidity_vs_latitude.png")

plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(WeatherPy_data["Latitude"], WeatherPy_data["Cloudiness"], marker="o", s=15)

plt.title("Latitude vs. Cloudiness")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

plt.savefig("../Output/cloudiness_vs_latitude.png")

plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(WeatherPy_data["Latitude"], WeatherPy_data["Winds"], marker="o", s=15)

plt.title("Latitude vs. Wind Speed")
plt.ylabel("Wind Speed")
plt.xlabel("Latitude")
plt.grid(True)

plt.savefig("../Output/wind_speed_vs_latitude.png")

plt.show()
